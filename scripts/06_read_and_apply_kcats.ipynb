# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Reading calibrated sMOMENT parameters and applying them to the models
#
# This script reads the outputs from the model calibration in Matlab. These outputs represent the change factors original kcats and protein pool variables need to be multiplied with.

# %%
import cobra
import pandas
import numpy as np
import json
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1) Read uncalibrated models and protein pools

# %%
smoment_models_dict = {
    'Mitocore_Preliminary': './../autopacmen_output/Mitocore_Preliminary/Mitocore_Preliminary_uncalibrated.xml',
    'Mitocore_MitoMammal': './../autopacmen_output/Mitocore_MitoMammal/Mitocore_MitoMammal_uncalibrated.xml',
    'Mitocore_aligned_to_Human1': './../autopacmen_output/Mitocore_aligned_to_Human1/Mitocore_aligned_to_Human1_uncalibrated.xml',
}

model_files = {}

for model_name in smoment_models_dict.keys():
    model_files[model_name] = {
        "kcat_mapping_path": f"./../autopacmen_output/{model_name}/{model_name}_reactions_kcat_mapping_combined.json",
        "calibrated_model_path": f"./../autopacmen_output/{model_name}/{model_name}_calibrated.xml",
        "protein_file_output": f'../model_data_input/{model_name}_protein_data',
        "mol_masses_mapping": f'../model_data_input/{model_name}_protein_id_mass_mapping.json',
        "calibrated_kcats_xlsx": f'./../autopacmen_output/{model_name}/{model_name}_kcats_calibrated.xlsx'
    }

# %%
original_kcats = {}

for model_name in smoment_models_dict.keys():
    with open(model_files[model_name]["kcat_mapping_path"]) as file:
        original_kcats[model_name] = json.load(file)

# %%
from utilities.utils import get_default_kcat

# get default kcat
# kcat is in 1/s, in model in 1/h
default_kcats = {}

for model_name in smoment_models_dict.keys():
    default_kcats[model_name] = get_default_kcat(original_kcats[model_name], 'median')
    print(f'{model_name} median kcat: ', default_kcats[model_name])
# Out:
# Mitocore_Preliminary median kcat:  11.7
# Mitocore_MitoMammal median kcat:  11.85
# Mitocore_aligned_to_Human1 median kcat:  9.95

# %% [markdown]
# ## 2) Read calibrated parameters

# %%
# read change factors
with open('./../autopacmen_output/calibrated_factors.json') as file:
    calibrated_params = json.load(file)

# %%
calibrated_params
# Out:
# {'Mitocore_Preliminary': {'reactions': {'R_CV_MitoCore_GPRSPLIT_3_TG_forward': 18.39217219539137,
#    'R_CV_MitoCore_GPRSPLIT_1_TG_forward': 18.39217219539137,
#    'R_CV_MitoCore_GPRSPLIT_2_TG_forward': 18.39217219539137,
#    'R_CI_MitoCore_GPRSPLIT_1_TG_forward': 50.271597983165954,
#    'R_PDHm_GPRSPLIT_1': 39.08584838682158,
#    'R_ACONTm_GPRSPLIT_1_TG_forward': 50.27158667096669,
#    'R_ACONT_GPRSPLIT_1_TG_forward': 50.27158689285316,
#    'R_SUCOASm_GPRSPLIT_1_TG_reverse': 50.271569239031834,
#    'R_GHMT2r_GPRSPLIT_1_TG_forward': 50.271586022984536,
#    'R_MCOATA_GPRSPLIT_1_TG_forward': 50.271586876361134,
#    'R_CIII_MitoCore_GPRSPLIT_1_TG_forward': 50.27156992277682,
#    'R_CIV_MitoCore_GPRSPLIT_1': 50.27158638559078,
#    'R_ICDHxm_GPRSPLIT_1': 50.271586679558865},
#   'bestPool': 0.11,
#   'newObjectiveVal': 2.1943661918793134},
#  'Mitocore_MitoMammal': {'reactions': {'R_CV_MitoCore_GPRSPLIT_1_TG_forward': 18.392172126689694,
#    'R_CV_MitoCore_GPRSPLIT_2_TG_forward': 18.392172126689694,
#    'R_CV_MitoCore_GPRSPLIT_3_TG_forward': 18.392172126689694,
#    'R_CIV_MitoCore_GPRSPLIT_6': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_1': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_2': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_3': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_4': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_5': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_7': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_8': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_9': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_10': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_11': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_12': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_13': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_14': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_15': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_16': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_17': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_18': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_19': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_20': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_21': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_22': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_23': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_24': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_25': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_26': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_27': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_28': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_29': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_30': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_31': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_32': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_33': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_34': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_35': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_36': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_37': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_38': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_39': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_40': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_41': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_42': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_43': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_44': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_45': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_46': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_47': 50.03954601442835,
#    'R_CIV_MitoCore_GPRSPLIT_48': 50.03954601442835,
#    'R_ACONTm_GPRSPLIT_1_TG_forward': 50.03953974956237,
#    'R_PDHm_GPRSPLIT_1': 49.72961798098989,
#    'R_ICDHxm_GPRSPLIT_1': 50.03954461185702,
#    'R_ACONT_GPRSPLIT_1_TG_forward': 50.039547056919126,
#    'R_SUCOASm_GPRSPLIT_1_TG_reverse': 50.03953991434766,
#    'R_CIII_MitoCore_GPRSPLIT_1_TG_forward': 50.039533647304324},
#   'bestPool': 0.14,
#   'newObjectiveVal': 2.1943661865464135},
#  'Mitocore_aligned_to_Human1': {'reactions': {'R_CV_MitoCore_GPRSPLIT_3_TG_forward': 18.392172184118962,
#    'R_CV_MitoCore_GPRSPLIT_1_TG_forward': 18.392172184118962,
#    'R_CV_MitoCore_GPRSPLIT_2_TG_forward': 18.392172184118962,
#    'R_CV_MitoCore_GPRSPLIT_4_TG_forward': 18.392172184118962,
#    'R_CIII_MitoCore_GPRSPLIT_2_TG_forward': 50.00509899564181,
#    'R_CIII_MitoCore_GPRSPLIT_1_TG_forward': 50.00509899564181,
#    'R_CIV_MitoCore_GPRSPLIT_12': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_2': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_3': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_4': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_5': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_6': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_7': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_8': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_9': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_10': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_11': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_13': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_14': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_15': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_16': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_17': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_18': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_19': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_20': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_21': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_22': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_23': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_24': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_25': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_26': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_27': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_28': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_29': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_30': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_31': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_32': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_33': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_34': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_35': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_36': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_37': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_38': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_39': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_40': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_41': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_42': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_43': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_44': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_45': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_46': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_47': 50.005207125328354,
#    'R_CIV_MitoCore_GPRSPLIT_48': 50.005207125328354,
#    'R_PDHm_GPRSPLIT_1': 50.00514884288962,
#    'R_PDHm_GPRSPLIT_2': 50.00514884288962,
#    'R_ACONTm_GPRSPLIT_1_TG_forward': 50.005392715254764,
#    'R_ICDHxm_GPRSPLIT_1': 50.00578509179749,
#    'R_ACONT_GPRSPLIT_2_TG_forward': 50.005171344297906,
#    'R_ACONT_GPRSPLIT_1_TG_forward': 50.005171344297906,
#    'R_GHMT2rm_GPRSPLIT_2_TG_forward': 50.005052250288635,
#    'R_GHMT2rm_GPRSPLIT_1_TG_forward': 50.005052250288635,
#    'R_SUCOASm_GPRSPLIT_3_TG_reverse': 50.00473272427084,
#    'R_SUCOASm_GPRSPLIT_1_TG_reverse': 50.00473272427084,
#    'R_SUCOASm_GPRSPLIT_2_TG_reverse': 50.00473272427084,
#    'R_r0178_GPRSPLIT_1': 50.00472263427194,
#    'R_GHMT2r_GPRSPLIT_1_TG_forward': 50.0059157303878},
#   'bestPool': 0.18,
#   'newObjectiveVal': 2.1943661910043035}}

# %% [markdown]
# ### 2.1) Get calibrated protein pools

# %%
# read original pool variables
prot_pool_dict = {'model': [], 'original_pool': [], 'calibrated_pool': []}

for model_name, path in smoment_models_dict.items():

    model = cobra.io.read_sbml_model(path)

    prot_pool_dict['model'].append(model_name)
    prot_pool_dict['original_pool'].append(model.reactions.ER_pool_TG_.upper_bound)

# %%
# plot the original vs calibrated pools
for model_index, model_name in enumerate(prot_pool_dict['model']):

    pool_stoichiometry = calibrated_params[model_name]['bestPool']

    new_pool = prot_pool_dict['original_pool'][model_index] * pool_stoichiometry

    prot_pool_dict['calibrated_pool'].append(new_pool)

# plot protein pools
models = prot_pool_dict['model']
x_positions = np.arange(len(models))
values = {key : prot_pool_dict[key] for key in ['original_pool', 'calibrated_pool']}

width = 0.25  # the width of the bars
multiplier = 0.1

fig, ax = plt.subplots(layout='constrained')
fig.set_size_inches(15, 8)

for key, value in values.items():
    offset = width * multiplier
    rects = ax.bar(x_positions + offset, value, width, label=key)
    ax.bar_label(rects, padding=3)
    multiplier += 1

ax.tick_params(axis='x', labelrotation=45)
ax.set_ylabel('Protein pool in g/gDW')
ax.set_title('Protein pool parameters')
ax.set_xticks(x_positions + width/2, models)
ax.legend(loc='upper left', ncols=3)
# ax.set_ylim(0, 0.015)
fig.autofmt_xdate()

plt.show()

# %% [markdown]
# ### 2.2) Get calibrated kcats

# %%
# create a matrix for every reaction that has been calibrated
# rows original reaction name (forward or reverse)
# columns original kcats, one column for every model

# some reactions have no kcat assigned, autoPACMEN automatically
# uses a default kcat (e.g., median) --> in the original kcats 
# there won't be a value and in the model_kcats_df a nan value

# reaction id additions:
# _GPRSPLIT_ is added to every reaction beeing split
# _TG_ is added to every reversible reaction

import re

model_data = {}

for model in calibrated_params.keys():

    model_kcats_dict = {'original_reactions': [], 'original_kcats': [], 'model_kcats': []}

    for reaction, factor in calibrated_params[model]['reactions'].items():

        reaction_id = re.sub('^R_','', reaction)
        original_reaction_id = reaction_id.split('_TG_')[0].split('_GPRSPLIT_')[0]

        original_reaction_kcats = original_kcats[model][original_reaction_id]

        directions = ['forward', 'reverse']
        if '_TG_' in reaction_id:
            directions = [reaction_id.split('_TG_')[1]]

        for direction in directions:
            original_kcat = original_reaction_kcats[direction]

            if str(original_kcat) == 'nan':
                original_kcat = default_kcats[model]

            model_kcats_dict['original_reactions'].append(original_reaction_id + "_" + direction)
            model_kcats_dict['original_kcats'].append(original_kcat)
            model_kcats_dict['model_kcats'].append(original_kcat*factor)
    
    model_kcats_df = pandas.DataFrame.from_dict(model_kcats_dict).drop_duplicates()
    model_kcats_df = model_kcats_df.set_index('original_reactions')
    model_data[model] = model_kcats_df

# %%
for model_name in smoment_models_dict.keys():
    pandas.DataFrame.to_excel(model_data[model_name], model_files[model_name]["calibrated_kcats_xlsx"])

# %% [markdown]
# # 3) Apply change factors to stoichiometric coefficients in model

# %%
from utilities.utils import apply_kcats_to_model

# iterate through models
for model_id, model_path in smoment_models_dict.items():
    
    if model_id not in calibrated_params.keys():
        continue

    calibrated_prot_pool = calibrated_params[model_id]['bestPool']
    calibration_factors = calibrated_params[model_id]['reactions']

    calibrated_model = apply_kcats_to_model(model_id, model_path, calibrated_prot_pool, calibration_factors)

    # write calibrated model
    model_output_path = model_files[model_id]['calibrated_model_path']

    cobra.io.write_sbml_model(calibrated_model, model_output_path)
# Out:
# Scaling Mitocore_Preliminary
# Scaled protein pool to {<Metabolite prot_pool at 0x274348aa800>: 0.11}
#
# Scaled CV_MitoCore_GPRSPLIT_3_TG_forward from
# CV_MitoCore_GPRSPLIT_3_TG_forward: 1.5015015015015e-05 ENZYME_ENSG00000099624 + 1.5015015015015e-05 ENZYME_ENSG00000110955 + 1.5015015015015e-05 ENZYME_ENSG00000116459 + 1.5015015015015e-05 ENZYME_ENSG00000124172 + 1.5015015015015e-05 ENZYME_ENSG00000152234 + 1.5015015015015e-05 ENZYME_ENSG00000154723 + 1.5015015015015e-05 ENZYME_ENSG00000165629 + 1.5015015015015e-05 ENZYME_ENSG00000167283 + 1.5015015015015e-05 ENZYME_ENSG00000167863 + 1.5015015015015e-05 ENZYME_ENSG00000169020 + 1.5015015015015e-05 ENZYME_ENSG00000198899 + 1.5015015015015e-05 ENZYME_ENSG00000228253 + 1.5015015015015e-05 ENZYME_ENSG00000241468 + 1.5015015015015e-05 ENZYME_ENSG00000241837 + 2.7 PMF_c + adp_m + h_m + pi_m + 0.00517507507507507 prot_pool --> 2.7 PMF_m + armm_CV_MitoCore_forward + atp_m + h2o_m to
# CV_MitoCore_GPRSPLIT_3_TG_forward: 8.163807328194434e-07 ENZYME_ENSG00000099624 + 8.163807328194434e-07 ENZYME_ENSG00000110955 + 8.163807328194434e-07 ENZYME_ENSG00000116459 + 8.163807328194434e-07 ENZYME_ENSG00000124172 + 8.163807328194434e-07 ENZYME_ENSG00000152234 + 8.163807328194434e-07 ENZYME_ENSG00000154723 + 8.163807328194434e-07 ENZYME_ENSG00000165629 + 8.163807328194434e-07 ENZYME_ENSG00000167283 + 8.163807328194434e-07 ENZYME_ENSG00000167863 + 8.163807328194434e-07 ENZYME_ENSG00000169020 + 8.163807328194434e-07 ENZYME_ENSG00000198899 + 8.163807328194434e-07 ENZYME_ENSG00000228253 + 8.163807328194434e-07 ENZYME_ENSG00000241468 + 8.163807328194434e-07 ENZYME_ENSG00000241837 + 2.7 PMF_c + adp_m + h_m + pi_m + 0.00028137378337354937 prot_pool --> 2.7 PMF_m + armm_CV_MitoCore_forward + atp_m + h2o_m
#
# Scaled CV_MitoCore_GPRSPLIT_1_TG_forward from
#
# Scaled ACONTm_GPRSPLIT_1_TG_forward from
# ACONTm_GPRSPLIT_1_TG_forward: 5.34188034188034e-05 ENZYME_ENSG00000100412 + cit_m + 0.00456330128205128 prot_pool --> icit_m to
# ACONTm_GPRSPLIT_1_TG_forward: 1.0626042851687893e-06 ENZYME_ENSG00000100412 + cit_m + 9.077297106054383e-05 prot_pool --> icit_m
#
# Scaled ACONT_GPRSPLIT_1_TG_forward from
# ACONT_GPRSPLIT_1_TG_forward: 5.34188034188034e-05 ENZYME_ENSG00000122729 + cit_c + 0.00525635683760684 prot_pool --> icit_c to
# ACONT_GPRSPLIT_1_TG_forward: 1.0626042804787143e-06 ENZYME_ENSG00000122729 + cit_c + 0.0001045591985948251 prot_pool --> icit_c
#
# Scaled SUCOASm_GPRSPLIT_1_TG_reverse from
# SUCOASm_GPRSPLIT_1_TG_reverse: 1.40291806958474e-05 ENZYME_ENSG00000136143 + adp_m + pi_m + 0.000705906285072952 prot_pool + succoa_m --> atp_m + coa_m + succ_m to
# SUCOASm_GPRSPLIT_1_TG_reverse: 2.7906788883277726e-07 ENZYME_ENSG00000136143 + adp_m + pi_m + 1.404185896239882e-05 prot_pool + succoa_m --> atp_m + coa_m + succ_m
#
# Scaled GHMT2r_GPRSPLIT_1_TG_forward from
# GHMT2r_GPRSPLIT_1_TG_forward: 0.000487329434697856 ENZYME_ENSG00000176974 + 0.0258689083820663 prot_pool + ser_L_c + thf_c --> gly_c + h2o_c + mlthf_c to
# GHMT2r_GPRSPLIT_1_TG_forward: 9.69393395456124e-06 ENZYME_ENSG00000176974 + 0.0005145830961099745 prot_pool + ser_L_c + thf_c --> gly_c + h2o_c + mlthf_c
#
# Scaled MCOATA_GPRSPLIT_1_TG_forward from
# MCOATA_GPRSPLIT_1_TG_forward: ACP_c + 2.31481481481481e-05 ENZYME_ENSG00000169710 + malcoa_c + 0.0063293287037037 prot_pool --> coa_c + malACP_c to
# MCOATA_GPRSPLIT_1_TG_forward: ACP_c + 4.6046185502516724e-07 ENZYME_ENSG00000169710 + malcoa_c + 0.00012590270363396658 prot_pool --> coa_c + malACP_c
#
# Scaled CIII_MitoCore_GPRSPLIT_1_TG_forward from
# CIII_MitoCore_GPRSPLIT_1_TG_forward: 3.51617440225035e-06 ENZYME_ENSG00000010256 + 3.51617440225035e-06 ENZYME_ENSG00000127540 + 3.51617440225035e-06 ENZYME_ENSG00000140740 + 3.51617440225035e-06 ENZYME_ENSG00000156467 + 3.51617440225035e-06 ENZYME_ENSG00000169021 + 3.51617440225035e-06 ENZYME_ENSG00000172115 + 3.51617440225035e-06 ENZYME_ENSG00000173660 + 3.51617440225035e-06 ENZYME_ENSG00000179091 + 2.0 PMF_m + 2.0 ficytC_m + 0.00105924753867792 prot_pool + q10h2_m --> 4.0 PMF_c + 2.0 focytC_m + q10_m to
# CIII_MitoCore_GPRSPLIT_1_TG_forward: 6.994359650298602e-08 ENZYME_ENSG00000010256 + 6.994359650298602e-08 ENZYME_ENSG00000127540 + 6.994359650298602e-08 ENZYME_ENSG00000140740 + 6.994359650298602e-08 ENZYME_ENSG00000156467 + 6.994359650298602e-08 ENZYME_ENSG00000169021 + 6.994359650298602e-08 ENZYME_ENSG00000172115 + 6.994359650298602e-08 ENZYME_ENSG00000173660 + 6.994359650298602e-08 ENZYME_ENSG00000179091 + 2.0 PMF_m + 2.0 ficytC_m + 2.1070508446524578e-05 prot_pool + q10h2_m --> 4.0 PMF_c + 2.0 focytC_m + q10_m
#
# Scaled CIV_MitoCore_GPRSPLIT_1 from
# CIV_MitoCore_GPRSPLIT_1: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000112695 + 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00226693642461359 prot_pool --> 4.0 PMF_c + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_1: 1.4502735732925112e-07 ENZYME_ENSG00000111775 + 1.4502735732925112e-07 ENZYME_ENSG00000112695 + 1.4502735732925112e-07 ENZYME_ENSG00000126267 + 1.4502735732925112e-07 ENZYME_ENSG00000127184 + 1.4502735732925112e-07 ENZYME_ENSG00000131143 + 1.4502735732925112e-07 ENZYME_ENSG00000135940 + 1.4502735732925112e-07 ENZYME_ENSG00000164919 + 1.4502735732925112e-07 ENZYME_ENSG00000178741 + 1.4502735732925112e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 4.5093791296456016e-05 prot_pool --> 4.0 PMF_c + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled ICDHxm_GPRSPLIT_1 from
# ICDHxm_GPRSPLIT_1: 1.3550135501355e-05 ENZYME_ENSG00000067829 + 1.3550135501355e-05 ENZYME_ENSG00000101365 + 1.3550135501355e-05 ENZYME_ENSG00000166411 + icit_m + nad_m + 0.00168794037940379 prot_pool --> akg_m + co2_m + nadh_m to
# ICDHxm_GPRSPLIT_1: 2.695386478991855e-07 ENZYME_ENSG00000067829 + 2.695386478991855e-07 ENZYME_ENSG00000101365 + 2.695386478991855e-07 ENZYME_ENSG00000166411 + icit_m + nad_m + 3.357642936880149e-05 prot_pool --> akg_m + co2_m + nadh_m
#
# objective value for Mitocore_Preliminary: 2.1943661918793125
#
#
# Scaling Mitocore_MitoMammal
# Scaled protein pool to {<Metabolite prot_pool at 0x2743f0dc7f0>: 0.14}
#
# Scaled CV_MitoCore_GPRSPLIT_1_TG_forward from
# CV_MitoCore_GPRSPLIT_1_TG_forward: 1.5015015015015e-05 ENZYME_ENSG00000099624 + 1.5015015015015e-05 ENZYME_ENSG00000110955 + 1.5015015015015e-05 ENZYME_ENSG00000116459 + 1.5015015015015e-05 ENZYME_ENSG00000124172 + 1.5015015015015e-05 ENZYME_ENSG00000152234 + 1.5015015015015e-05 ENZYME_ENSG00000154723 + 1.5015015015015e-05 ENZYME_ENSG00000165629 + 1.5015015015015e-05 ENZYME_ENSG00000167283 + 1.5015015015015e-05 ENZYME_ENSG00000167863 + 1.5015015015015e-05 ENZYME_ENSG00000169020 + 1.5015015015015e-05 ENZYME_ENSG00000198899 + 1.5015015015015e-05 ENZYME_ENSG00000228253 + 1.5015015015015e-05 ENZYME_ENSG00000241468 + 1.5015015015015e-05 ENZYME_ENSG00000241837 + 2.7 PMF_c + adp_m + h_m + pi_m + 0.00516882882882883 prot_pool --> 2.7 PMF_m + armm_CV_MitoCore_forward + atp_m + h2o_m to
#
# Scaled CV_MitoCore_GPRSPLIT_3_TG_forward from
# CV_MitoCore_GPRSPLIT_3_TG_forward: 1.5015015015015e-05 ENZYME_ENSG00000099624 + 1.5015015015015e-05 ENZYME_ENSG00000110955 + 1.5015015015015e-05 ENZYME_ENSG00000116459 + 1.5015015015015e-05 ENZYME_ENSG00000124172 + 1.5015015015015e-05 ENZYME_ENSG00000152234 + 1.5015015015015e-05 ENZYME_ENSG00000154723 + 1.5015015015015e-05 ENZYME_ENSG00000165629 + 1.5015015015015e-05 ENZYME_ENSG00000167283 + 1.5015015015015e-05 ENZYME_ENSG00000167863 + 1.5015015015015e-05 ENZYME_ENSG00000169020 + 1.5015015015015e-05 ENZYME_ENSG00000198899 + 1.5015015015015e-05 ENZYME_ENSG00000228253 + 1.5015015015015e-05 ENZYME_ENSG00000241468 + 1.5015015015015e-05 ENZYME_ENSG00000241837 + 2.7 PMF_c + adp_m + h_m + pi_m + 0.00517507507507507 prot_pool --> 2.7 PMF_m + armm_CV_MitoCore_forward + atp_m + h2o_m to
# CV_MitoCore_GPRSPLIT_3_TG_forward: 8.163807358689324e-07 ENZYME_ENSG00000099624 + 8.163807358689324e-07 ENZYME_ENSG00000110955 + 8.163807358689324e-07 ENZYME_ENSG00000116459 + 8.163807358689324e-07 ENZYME_ENSG00000124172 + 8.163807358689324e-07 ENZYME_ENSG00000152234 + 8.163807358689324e-07 ENZYME_ENSG00000154723 + 8.163807358689324e-07 ENZYME_ENSG00000165629 + 8.163807358689324e-07 ENZYME_ENSG00000167283 + 8.163807358689324e-07 ENZYME_ENSG00000167863 + 8.163807358689324e-07 ENZYME_ENSG00000169020 + 8.163807358689324e-07 ENZYME_ENSG00000198899 + 8.163807358689324e-07 ENZYME_ENSG00000228253 + 8.163807358689324e-07 ENZYME_ENSG00000241468 + 8.163807358689324e-07 ENZYME_ENSG00000241837 + 2.7 PMF_c + adp_m + h_m + pi_m + 0.00028137378442458623 prot_pool --> 2.7 PMF_m + armm_CV_MitoCore_forward + atp_m + h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_6 from
# CIV_MitoCore_GPRSPLIT_6: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.0016832239720035 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_6: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.363787456261415e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_1 from
# CIV_MitoCore_GPRSPLIT_1: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00165371828521435 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_1: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.304822719090054e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_2 from
# CIV_MitoCore_GPRSPLIT_2: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00165772820064159 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_2: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.31283621191048e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_3 from
# CIV_MitoCore_GPRSPLIT_3: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000112695 + 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00165574511519393 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_3: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000112695 + 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.3088731754610924e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_4 from
# CIV_MitoCore_GPRSPLIT_4: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000112695 + 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00165975503062117 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_4: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000112695 + 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.316886668281519e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_5 from
# CIV_MitoCore_GPRSPLIT_5: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00167921405657626 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_5: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.3557739634409895e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_7 from
# CIV_MitoCore_GPRSPLIT_7: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00165617526975795 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_7: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.3097328046909344e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_8 from
# CIV_MitoCore_GPRSPLIT_8: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00166018518518519 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_8: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.31774629751136e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_9 from
# CIV_MitoCore_GPRSPLIT_9: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000112695 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00165820209973753 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_9: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000112695 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.313783261061972e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_10 from
# CIV_MitoCore_GPRSPLIT_10: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000112695 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00166221201516477 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_10: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000112695 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.321796753882398e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_11 from
# CIV_MitoCore_GPRSPLIT_11: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00168167104111986 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_11: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.360684049041869e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_12 from
# CIV_MitoCore_GPRSPLIT_12: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.0016856809565471 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_12: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.368697541862295e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_13 from
# CIV_MitoCore_GPRSPLIT_13: 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00164394867308253 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_13: 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.285298936582109e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_14 from
# CIV_MitoCore_GPRSPLIT_14: 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00164795858850977 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_14: 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.2933124294025353e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_15 from
# CIV_MitoCore_GPRSPLIT_15: 7.29075532225139e-06 ENZYME_ENSG00000112695 + 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00164597550306212 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_15: 1.4569986946222854e-07 ENZYME_ENSG00000112695 + 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.289349392953167e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_16 from
# CIV_MitoCore_GPRSPLIT_16: 7.29075532225139e-06 ENZYME_ENSG00000112695 + 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00164998541848936 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_16: 1.4569986946222854e-07 ENZYME_ENSG00000112695 + 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.2973628857735936e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_17 from
# CIV_MitoCore_GPRSPLIT_17: 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00166944444444444 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_17: 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.336250180933045e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_18 from
# CIV_MitoCore_GPRSPLIT_18: 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00167345435987168 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_18: 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.3442636737534703e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_19 from
# CIV_MitoCore_GPRSPLIT_19: 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00164640565762613 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_19: 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.290209022182989e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_20 from
# CIV_MitoCore_GPRSPLIT_20: 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00165041557305337 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_20: 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.298222515003415e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_21 from
# CIV_MitoCore_GPRSPLIT_21: 7.29075532225139e-06 ENZYME_ENSG00000112695 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00164843248760572 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_21: 1.4569986946222854e-07 ENZYME_ENSG00000112695 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.294259478554047e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_22 from
# CIV_MitoCore_GPRSPLIT_22: 7.29075532225139e-06 ENZYME_ENSG00000112695 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00165244240303295 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_22: 1.4569986946222854e-07 ENZYME_ENSG00000112695 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.302272971374453e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_23 from
# CIV_MitoCore_GPRSPLIT_23: 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00167190142898804 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_23: 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.341160266533924e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_24 from
# CIV_MitoCore_GPRSPLIT_24: 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000131143 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00167591134441528 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_24: 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000131143 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.34917375935435e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_25 from
# CIV_MitoCore_GPRSPLIT_25: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00165687518226888 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_25: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.311131523437759e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_26 from
# CIV_MitoCore_GPRSPLIT_26: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00166088509769612 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_26: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.3191450162581854e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_27 from
# CIV_MitoCore_GPRSPLIT_27: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000112695 + 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00165890201224847 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_27: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000112695 + 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.3151819798088174e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_28 from
# CIV_MitoCore_GPRSPLIT_28: 7.29075532225139e-06 ENZYME_ENSG00000111775 + 7.29075532225139e-06 ENZYME_ENSG00000112695 + 7.29075532225139e-06 ENZYME_ENSG00000126267 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00166291192767571 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_28: 1.4569986946222854e-07 ENZYME_ENSG00000111775 + 1.4569986946222854e-07 ENZYME_ENSG00000112695 + 1.4569986946222854e-07 ENZYME_ENSG00000126267 + 1.4569986946222854e-07 ENZYME_ENSG00000127184 + 1.4569986946222854e-07 ENZYME_ENSG00000135940 + 1.4569986946222854e-07 ENZYME_ENSG00000164919 + 1.4569986946222854e-07 ENZYME_ENSG00000178741 + 1.4569986946222854e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.323195472629243e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_29 from
# ...
# CIV_MitoCore_GPRSPLIT_37: 1.457999224756439e-07 ENZYME_ENSG00000126267 + 1.457999224756439e-07 ENZYME_ENSG00000127184 + 1.457999224756439e-07 ENZYME_ENSG00000135940 + 1.457999224756439e-07 ENZYME_ENSG00000164919 + 1.457999224756439e-07 ENZYME_ENSG00000178741 + 1.457999224756439e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3
prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_45: 1.457999224756439e-07 ENZYME_ENSG00000112695 + 1.457999224756439e-07 ENZYME_ENSG00000127184 + 1.457999224756439e-07 ENZYME_ENSG00000135940 + 1.457999224756439e-07 ENZYME_ENSG00000164919 + 1.457999224756439e-07 ENZYME_ENSG00000178741 + 1.457999224756439e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.3028348038252524e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_46 from
# CIV_MitoCore_GPRSPLIT_46: 7.29075532225139e-06 ENZYME_ENSG00000112695 + 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00165559930008749 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_46: 1.457999224756439e-07 ENZYME_ENSG00000112695 + 1.457999224756439e-07 ENZYME_ENSG00000127184 + 1.457999224756439e-07 ENZYME_ENSG00000135940 + 1.457999224756439e-07 ENZYME_ENSG00000164919 + 1.457999224756439e-07 ENZYME_ENSG00000178741 + 1.457999224756439e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.3108537995614166e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_47 from
# CIV_MitoCore_GPRSPLIT_47: 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00167505832604258 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_47: 1.457999224756439e-07 ENZYME_ENSG00000127184 + 1.457999224756439e-07 ENZYME_ENSG00000135940 + 1.457999224756439e-07 ENZYME_ENSG00000164919 + 1.457999224756439e-07 ENZYME_ENSG00000178741 + 1.457999224756439e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.349767798870168e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled CIV_MitoCore_GPRSPLIT_48 from
# CIV_MitoCore_GPRSPLIT_48: 7.29075532225139e-06 ENZYME_ENSG00000127184 + 7.29075532225139e-06 ENZYME_ENSG00000135940 + 7.29075532225139e-06 ENZYME_ENSG00000164919 + 7.29075532225139e-06 ENZYME_ENSG00000178741 + 7.29075532225139e-06 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 0.00167906824146982 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m to
# CIV_MitoCore_GPRSPLIT_48: 1.457999224756439e-07 ENZYME_ENSG00000127184 + 1.457999224756439e-07 ENZYME_ENSG00000135940 + 1.457999224756439e-07 ENZYME_ENSG00000164919 + 1.457999224756439e-07 ENZYME_ENSG00000178741 + 1.457999224756439e-07 ENZYME_ENSG00000198712 + 8.0 PMF_m + 4.0 focytC_m + o2_m + 3.3577867946063315e-05 prot_pool --> 4.0 PMF_c + armm_CIV_MitoCore + 4.0 ficytC_m + 2.0 h2o_m
#
# Scaled PDHm_GPRSPLIT_1 from
# PDHm_GPRSPLIT_1: 8.6955009478096e-06 ENZYME_ENSG00000091140 + 8.6955009478096e-06 ENZYME_ENSG00000131828 + 8.6955009478096e-06 ENZYME_ENSG00000150768 + 8.6955009478096e-06 ENZYME_ENSG00000168291 + coa_m + nad_m + 0.00178869063146728 prot_pool + pyr_m --> accoa_m + armm_PDHm + co2_m + nadh_m to
# PDHm_GPRSPLIT_1: 1.738921120928938e-07 ENZYME_ENSG00000091140 + 1.738921120928938e-07 ENZYME_ENSG00000131828 + 1.738921120928938e-07 ENZYME_ENSG00000150768 + 1.738921120928938e-07 ENZYME_ENSG00000168291 + coa_m + nad_m + 3.577012913384457e-05 prot_pool + pyr_m --> accoa_m + armm_PDHm + co2_m + nadh_m
#
# Scaled PDHm_GPRSPLIT_2 from
# PDHm_GPRSPLIT_2: 8.6955009478096e-06 ENZYME_ENSG00000110435 + 8.6955009478096e-06 ENZYME_ENSG00000150768 + coa_m + nad_m + 0.00107058138119337 prot_pool + pyr_m --> accoa_m + armm_PDHm + co2_m + nadh_m to
# PDHm_GPRSPLIT_2: 1.738921120928938e-07 ENZYME_ENSG00000110435 + 1.738921120928938e-07 ENZYME_ENSG00000150768 + coa_m + nad_m + 2.1409422948764988e-05 prot_pool + pyr_m --> accoa_m + armm_PDHm + co2_m + nadh_m
#
# Scaled ACONTm_GPRSPLIT_1_TG_forward from
# ACONTm_GPRSPLIT_1_TG_forward: 5.34188034188034e-05 ENZYME_ENSG00000100412 + cit_m + 0.00456330128205128 prot_pool --> icit_m to
# ACONTm_GPRSPLIT_1_TG_forward: 1.0682608518442318e-06 ENZYME_ENSG00000100412 + cit_m + 9.12561832687935e-05 prot_pool --> icit_m
#
# Scaled ICDHxm_GPRSPLIT_1 from
# ICDHxm_GPRSPLIT_1: 2.30840322485777e-05 ENZYME_ENSG00000067829 + 2.30840322485777e-05 ENZYME_ENSG00000101365 + 2.30840322485777e-05 ENZYME_ENSG00000166411 + icit_m + nad_m + 0.00287557789720533 prot_pool --> akg_m + co2_m + nadh_m to
# ICDHxm_GPRSPLIT_1: 4.616272338530728e-07 ENZYME_ENSG00000067829 + 4.616272338530728e-07 ENZYME_ENSG00000101365 + 4.616272338530728e-07 ENZYME_ENSG00000166411 + icit_m + nad_m + 5.7504904521077386e-05 prot_pool --> akg_m + co2_m + nadh_m
#
# Scaled ACONT_GPRSPLIT_2_TG_forward from
# ACONT_GPRSPLIT_2_TG_forward: 5.34188034188034e-05 ENZYME_ENSG00000100412 + cit_c + 0.00456330128205128 prot_pool --> armm_ACONT_forward + icit_c to
# ACONT_GPRSPLIT_2_TG_forward: 1.0682655809936496e-06 ENZYME_ENSG00000100412 + cit_c + 9.125658725638252e-05 prot_pool --> armm_ACONT_forward + icit_c
#
# Scaled ACONT_GPRSPLIT_1_TG_forward from
# ACONT_GPRSPLIT_1_TG_forward: 5.34188034188034e-05 ENZYME_ENSG00000122729 + cit_c + 0.00525635683760684 prot_pool --> armm_ACONT_forward + icit_c to
# ACONT_GPRSPLIT_1_TG_forward: 1.0682655809936496e-06 ENZYME_ENSG00000122729 + cit_c + 0.0001051162649041942 prot_pool --> armm_ACONT_forward + icit_c
#
# Scaled GHMT2rm_GPRSPLIT_2_TG_forward from
# GHMT2rm_GPRSPLIT_2_TG_forward: 0.000487329434697856 ENZYME_ENSG00000176974 + 0.0258689083820663 prot_pool + ser_L_m + thf_m --> armm_GHMT2rm_forward + gly_m + h2o_m + mlthf_m to
# GHMT2rm_GPRSPLIT_2_TG_forward: 9.7456039493498e-06 ENZYME_ENSG00000176974 + 0.0005173258944433356 prot_pool + ser_L_m + thf_m --> armm_GHMT2rm_forward + gly_m + h2o_m + mlthf_m
#
# Scaled GHMT2rm_GPRSPLIT_1_TG_forward from
# GHMT2rm_GPRSPLIT_1_TG_forward: 0.000487329434697856 ENZYME_ENSG00000182199 + 0.027287037037037 prot_pool + ser_L_m + thf_m --> armm_GHMT2rm_forward + gly_m + h2o_m + mlthf_m to
# GHMT2rm_GPRSPLIT_1_TG_forward: 9.7456039493498e-06 ENZYME_ENSG00000182199 + 0.0005456856019359422 prot_pool + ser_L_m + thf_m --> armm_GHMT2rm_forward + gly_m + h2o_m + mlthf_m
#
# Scaled SUCOASm_GPRSPLIT_3_TG_reverse from
# SUCOASm_GPRSPLIT_3_TG_reverse: 1.40291806958474e-05 ENZYME_ENSG00000136143 + 1.40291806958474e-05 ENZYME_ENSG00000163541 + adp_m + pi_m + 0.00121446408529742 prot_pool + succoa_m --> armm_SUCOASm_reverse + atp_m + coa_m + succ_m to
# SUCOASm_GPRSPLIT_3_TG_reverse: 2.805570579329993e-07 ENZYME_ENSG00000136143 + 2.805570579329993e-07 ENZYME_ENSG00000163541 + adp_m + pi_m + 2.4286982834085914e-05 prot_pool + succoa_m --> armm_SUCOASm_reverse + atp_m + coa_m + succ_m
#
# Scaled SUCOASm_GPRSPLIT_1_TG_reverse from
# SUCOASm_GPRSPLIT_1_TG_reverse: 1.40291806958474e-05 ENZYME_ENSG00000136143 + adp_m + pi_m + 0.000705906285072952 prot_pool + succoa_m --> armm_SUCOASm_reverse + atp_m + coa_m + succ_m to
# SUCOASm_GPRSPLIT_1_TG_reverse: 2.805570579329993e-07 ENZYME_ENSG00000136143 + adp_m + pi_m + 1.4116789484014694e-05 prot_pool + succoa_m --> armm_SUCOASm_reverse + atp_m + coa_m + succ_m
#
# Scaled SUCOASm_GPRSPLIT_2_TG_reverse from
# SUCOASm_GPRSPLIT_2_TG_reverse: 1.40291806958474e-05 ENZYME_ENSG00000163541 + 1.40291806958474e-05 ENZYME_ENSG00000172340 + adp_m + pi_m + 0.00116106902356902 prot_pool + succoa_m --> armm_SUCOASm_reverse + atp_m + coa_m + succ_m to
# SUCOASm_GPRSPLIT_2_TG_reverse: 2.805570579329993e-07 ENZYME_ENSG00000163541 + 2.805570579329993e-07 ENZYME_ENSG00000172340 + adp_m + pi_m + 2.3219182671592824e-05 prot_pool + succoa_m --> armm_SUCOASm_reverse + atp_m + coa_m + succ_m
#
# Scaled r0178_GPRSPLIT_1 from
# r0178_GPRSPLIT_1: 1.0231225700839e-05 ENZYME_ENSG00000112294 + h2o_m + nad_m + 0.000585379578473501 prot_pool + sucsal_m --> 2.0 h_m + nadh_m + succ_m to
# r0178_GPRSPLIT_1: 2.0460518850727077e-07 ENZYME_ENSG00000112294 + h2o_m + nad_m + 1.1706485860443448e-05 prot_pool + sucsal_m --> 2.0 h_m + nadh_m + succ_m
#
# Scaled GHMT2r_GPRSPLIT_1_TG_forward from
# GHMT2r_GPRSPLIT_1_TG_forward: 0.000487329434697856 ENZYME_ENSG00000176974 + 0.0258689083820663 prot_pool + ser_L_c + thf_c --> gly_c + h2o_c + mlthf_c to
# GHMT2r_GPRSPLIT_1_TG_forward: 9.74543566655882e-06 ENZYME_ENSG00000176974 + 0.0005173169614879421 prot_pool + ser_L_c + thf_c --> gly_c + h2o_c + mlthf_c
#
# objective value for Mitocore_aligned_to_Human1: 2.1943661910043026
